# %%
""" test code fo this repo """
# Out:
# ' test code fo this repo '

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## logger.py
# * func `init_logger`

# %%
from src.logger import init_logger
from src.utils import mkdir

# %%
logger_dir = 'logs'
logger_name = 'TEST'
level = 'DEBUG'

logger = init_logger(logger_dir=logger_dir, logger_name=logger_name, level=level)

# %%
logger.info('[TEST] This is a testing message.')
# Out:
# [2021-01-25 23:21:16,838][INFO][TEST] This is a testing message.

# %% [markdown]
# ## data.py
# * class `TabularDataset`
# * func `create_data_loader`

# %% [markdown]
# ### class `TabularDataset`

# %%
from sklearn.datasets import load_boston
from src.core import data

# %% [markdown]
# #### training/evaluation dataset

# %%
 X, y = load_boston(return_X_y=True)
cates_feats = np.random.choice((0, 1, 2), size=X.shape[0])

print('X : ', X.shape)
print('cates_feats : ', cates_feats.shape)
print(cates_feats)

cate_X = np.hstack((X, cates_feats.reshape(-1, 1)))
print(cate_X.shape)
# Out:
# X :  (506, 13)
# cates_feats :  (506,)
# [0 1 0 1 2 1 1 1 2 2 0 2 0 0 2 2 2 0 0 2 1 2 0 1 1 2 1 2 0 0 1 2 0 1 1 0 1
#  2 0 2 1 0 0 1 1 0 2 0 2 0 1 2 0 0 0 0 0 1 2 2 0 2 0 1 0 1 0 0 1 0 0 2 0 1
#  0 0 1 2 2 0 2 2 2 2 0 0 0 0 1 0 2 2 2 2 0 2 2 0 2 0 2 0 2 1 0 2 0 0 1 1 1
#  1 2 0 2 0 0 0 0 2 1 2 2 1 0 2 0 2 0 1 2 1 0 2 1 2 1 1 1 0 2 0 0 0 1 1 2 2
#  2 0 2 1 1 1 0 2 1 2 0 0 1 0 2 2 1 0 1 1 0 2 2 1 1 2 2 2 0 0 2 0 2 0 1 0 0
#  0 0 0 1 0 2 0 2 0 1 0 0 1 0 2 1 0 1 0 0 1 1 1 0 1 1 1 0 2 2 2 1 1 2 0 1 2
#  1 0 2 0 0 2 1 0 1 1 2 0 1 0 2 2 0 1 1 1 2 1 0 2 1 0 2 1 0 0 0 0 0 2 2 0 1
#  0 2 2 2 1 0 1 0 0 0 2 1 0 0 1 1 1 2 0 1 2 0 2 1 1 0 2 2 2 0 2 2 1 0 2 0 0
#  0 1 0 0 2 2 0 2 2 2 1 2 2 1 0 0 0 2 2 1 1 1 0 1 2 2 1 0 2 2 1 0 0 2 2 1 1
#  0 2 0 1 1 2 1 2 0 2 0 1 0 0 1 2 0 2 1 2 2 2 1 2 2 2 2 1 0 0 1 0 0 2 1 0 1
#  1 0 1 1 0 0 2 0 2 0 2 2 1 2 1 1 0 0 1 1 1 1 1 2 0 0 0 2 0 1 0 1 0 2 2 2 0
#  1 2 1 2 1 1 0 2 0 0 0 2 1 2 1 0 1 0 0 0 1 2 1 1 1 1 0 0 1 2 0 1 0 0 2 1 1
# ...

# %%
dataset = data.TabularDataset(feats=cate_X, targets=y)

# %%
n_limit = 10

for i in range(len(dataset)):
    _x, _y = dataset[i]
    print(_x)
    print(_y)
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00 0.000e+00]
# 24.0
# [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#  7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#  9.1400e+00 1.0000e+00]
# 21.6
# [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#  6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#  4.0300e+00 0.0000e+00]
# 34.7
# [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#  4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#  2.9400e+00 1.0000e+00]
# 33.4
# [6.9050e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 7.1470e+00
#  5.4200e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9690e+02
#  5.3300e+00 2.0000e+00]
# 36.2
# [2.9850e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.4300e+00
#  5.8700e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9412e+02
# ...

# %% [markdown]
# #### inference dataset

# %%
infer_dataset = data.TabularDataset(feats=cate_X, targets=None)

# %%
n_limit = 10

for i in range(len(infer_dataset)):
    _x = infer_dataset[i]
    print(_x)
# Out:
# [6.320e-03 1.800e+01 2.310e+00 0.000e+00 5.380e-01 6.575e+00 6.520e+01
#  4.090e+00 1.000e+00 2.960e+02 1.530e+01 3.969e+02 4.980e+00 0.000e+00]
# [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#  7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#  9.1400e+00 1.0000e+00]
# [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#  6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#  4.0300e+00 0.0000e+00]
# [3.2370e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.9980e+00
#  4.5800e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9463e+02
#  2.9400e+00 1.0000e+00]
# [6.9050e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 7.1470e+00
#  5.4200e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9690e+02
#  5.3300e+00 2.0000e+00]
# [2.9850e-02 0.0000e+00 2.1800e+00 0.0000e+00 4.5800e-01 6.4300e+00
#  5.8700e+01 6.0622e+00 3.0000e+00 2.2200e+02 1.8700e+01 3.9412e+02
#  5.2100e+00 1.0000e+00]
# ...

# %% [markdown]
# ### func `create_data_loader`

# %%
data_loader = data.create_data_loader(cate_X, y, batch_size=32, is_shuffle=True, num_workers=1, pin_memory=False)

# %%
for loaded_data in data_loader:
    batch_X, batch_y = loaded_data
    print(batch_X.size())
    print(batch_y.size())
# Out:
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([32, 14])
# torch.Size([32])
# torch.Size([26, 14])
# torch.Size([26])

# %% [markdown]
# ## Network Architectures

# %% [markdown]
# ## TabNet Model Classes
# * class `TabNetRegressor`
# * class `TabNetRegressor`
# * Customized model

# %% [markdown]
# ### class `TabNetRegressor`

# %%
from src.builtin.estimators import TabNetRegressor

# %%
tabnet = TabNetRegressor(
    input_dims=14, output_dims=[1], logger=logger
)

# %%
print('model : ', tabnet._model)
print('criterion : ', tabnet._criterion)
print('optimizer : ', tabnet._optimizer)
# Out:
# model :  None
# criterion :  Criterion(
#   (_loss_layers): ModuleList(
#     (0): MSELoss()
#   )
# )
# optimizer :  None

# %%
tabnet.load_weights(path='11111')
# Out:
# [Errno 2] No such file or directory: '11111'
# [2021-01-25 23:21:19,295][WARNING][TabNet] Failed to load model from 11111
# [2021-01-25 23:21:19,296][DEBUG][Errno 2] No such file or directory: '11111'
# TabNetRegressor(input_dims=14, logger=<RootLogger root (DEBUG)>,
#                 output_dims=[1])

# %%
tabnet.show_model()
# Out:
# [2021-01-25 23:21:19,305][INFO][TabNet] show model architecture.
# InferenceModel(
#   (embedding_encoder): EmbeddingEncoder()
#   (tabnet_encoder): TabNetEncoder(
#     (input_bn): BatchNorm1d(14, eps=1e-05, momentum=0.03, affine=True, track_running_stats=True)
#     (input_splitter): FeatureTransformer(
#       (shared_block): FeatureBlock(
#         (shared_layers): ModuleList(
#           (0): Linear(in_features=14, out_features=32, bias=False)
#           (1): Linear(in_features=16, out_features=32, bias=False)
#         )
#         (glu_blocks): ModuleList(
#           (0): GLUBlock(
#             (fc): Linear(in_features=14, out_features=32, bias=False)
#             (gbn): GhostBatchNorm(
#               (bn): BatchNorm1d(32, eps=1e-05, momentum=0.03, affine=True, track_running_stats=True)
#             )
#           )
#           (1): GLUBlock(
#             (fc): Linear(in_features=16, out_features=32, bias=False)
#             (gbn): GhostBatchNorm(
# ...

# %%
tabnet.get_params()
# Out:
# {'atten_dims': 8,
#  'batch_size': 1024,
#  'cate_dims': None,
#  'cate_embed_dims': 1,
#  'cate_indices': None,
#  'gamma': 1.3,
#  'input_dims': 14,
#  'is_cuda': False,
#  'is_shuffle': True,
#  'logger': <RootLogger root (DEBUG)>,
#  'mask_type': 'sparsemax',
#  'momentum': 0.03,
#  'num_indep': 2,
#  'num_shared': 2,
#  'num_steps': 3,
#  'num_workers': 4,
#  'output_dims': [1],
#  'pin_memory': True,
#  'reprs_dims': 8,
#  'task_weights': 1,
#  'virtual_batch_size': 128}

# %%
tabnet.model_confgs_
# Out:
# {'input_dims': 14,
#  'output_dims': [1],
#  'cate_indices': None,
#  'cate_dims': None,
#  'cate_embed_dims': 1,
#  'reprs_dims': 8,
#  'atten_dims': 8,
#  'num_steps': 3,
#  'gamma': 1.3,
#  'num_indep': 2,
#  'num_shared': 2,
#  'virtual_batch_size': 128,
#  'momentum': 0.03,
#  'mask_type': 'sparsemax'}

# %%
predictions = tabnet.predict(cate_X)

# %%
print(predictions[0].shape)
print(cate_X.shape)
# Out:
# (506, 1)
# (506, 14)

# %%
type(predictions[0])
# Out:
# numpy.ndarray

# %% [markdown]
# ### class `TabNetClassifier`

# %%
from src.builtin.estimators import TabNetClassifier
from sklearn.datasets import load_breast_cancer

# %%
X, y = load_breast_cancer(return_X_y=True)

# %%
print(np.unique(y))
print(X.shape)
print(X[0, ...])
# Out:
# [0 1]
# (569, 30)
# [1.799e+01 1.038e+01 1.228e+02 1.001e+03 1.184e-01 2.776e-01 3.001e-01
#  1.471e-01 2.419e-01 7.871e-02 1.095e+00 9.053e-01 8.589e+00 1.534e+02
#  6.399e-03 4.904e-02 5.373e-02 1.587e-02 3.003e-02 6.193e-03 2.538e+01
#  1.733e+01 1.846e+02 2.019e+03 1.622e-01 6.656e-01 7.119e-01 2.654e-01
#  4.601e-01 1.189e-01]

# %%
tabnet = TabNetClassifier(
    input_dims=30, output_dims=[1], logger=logger
)

# %%
print('model : ', tabnet._model)
print('criterion : ', tabnet._criterion)
print('optimizer : ', tabnet._optimizer)
# Out:
# model :  None
# criterion :  Criterion(
#   (_loss_layers): ModuleList(
#     (0): BCELoss()
#   )
# )
# optimizer :  None

# %%
tabnet.load_weights(model_type='inference_model', path='xxxx')
# Out:
# [Errno 2] No such file or directory: 'xxxx'
# [2021-01-25 23:21:22,871][WARNING][TabNet] Failed to load model from xxxx
# [2021-01-25 23:21:22,872][DEBUG][Errno 2] No such file or directory: 'xxxx'
# TabNetClassifier(input_dims=30, logger=<RootLogger root (DEBUG)>,
#                  output_dims=[1])

# %%
predictions = tabnet.predict(X)
# Out:
# tensor([[ 2.4414e+01],
#         [ 6.7551e+00],
#         [ 2.2041e+01],
#         [ 9.7204e+02],
#         [ 4.0527e+02],
#         [ 2.3880e+01],
#         [ 4.1329e+01],
#         [ 4.8868e+02],
#         [ 7.1978e+02],
#         [ 4.1018e+01],
#         [ 9.6931e+00],
#         [ 9.4367e+02],
#         [ 7.6211e+02],
#         [ 4.9522e+01],
#         [ 4.8477e-01],
#         [ 1.6798e+01],
#         [ 1.1985e+01],
#         [ 8.7960e+01],
#         [ 4.3764e+01],
#         [ 1.0085e+01],
#         [ 1.1372e+01],
#         [ 3.0095e+01],
#         [-5.6781e-01],
#         [ 1.5131e+01],
#         [ 2.6668e+02],
#         [ 1.3594e+01],
#         [ 1.0423e+03],
#         [ 7.9995e+01],
#         [ 1.0157e+03],
#         [ 5.3384e+01],
#         [ 9.8526e+02],
#         [-6.2834e-01],
#         [ 3.8554e+01],
#         [ 7.5458e+00],
#         [ 3.1319e+01],
#         [-2.2157e+00],
#         [ 2.0299e+01],
#         [-1.1615e+00],
#         [ 4.3414e+02],
#         [ 5.9029e+00],
# ...

# %%
probs = tabnet.predict_proba(X)
# Out:
# tensor([[ 5.3384e+01],
#         [ 2.1532e+01],
#         [ 5.7628e+00],
#         [ 1.3594e+01],
#         [ 5.4016e+02],
#         [ 4.2254e+02],
#         [ 1.1979e+01],
#         [ 7.1126e+02],
#         [ 2.4124e+02],
#         [ 1.1232e+03],
#         [ 1.0441e+03],
#         [ 1.1985e+01],
#         [ 1.0438e+03],
#         [ 2.7973e+02],
#         [ 7.2280e+02],
#         [-1.4252e+00],
#         [ 1.9797e+02],
#         [ 1.0131e+03],
#         [ 2.9043e+02],
#         [-5.2880e-01],
#         [ 1.0823e+01],
#         [ 2.8071e+02],
#         [ 1.7622e+02],
#         [ 1.1080e+01],
#         [ 2.4567e+02],
#         [ 1.8719e+01],
#         [ 5.7782e+00],
#         [ 1.3538e+03],
#         [ 1.5581e+03],
#         [ 2.9481e+02],
#         [ 4.9413e+02],
#         [ 1.8878e+01],
#         [ 1.7241e+02],
#         [ 1.7125e+02],
#         [ 1.1354e+03],
#         [ 1.0808e+03],
#         [ 2.3135e+02],
#         [ 1.3393e+03],
#         [ 7.1978e+02],
#         [ 1.0793e+03],
# ...

# %%
print(probs[0].shape)
print(np.unique(probs[0]))
# Out:
# (569, 1)
# [1.3567261e-34 6.2008361e-30 6.0741639e-27 2.0883598e-20 1.8535444e-15
#  2.4772893e-05 9.5280983e-02 9.8345235e-02 1.0273040e-01 1.0761214e-01
#  1.5191703e-01 1.9384512e-01 1.9889653e-01 1.9939783e-01 2.0271838e-01
#  2.0304890e-01 2.0929398e-01 2.2633737e-01 2.3647766e-01 2.3839594e-01
#  3.0413729e-01 3.0435470e-01 3.0614361e-01 3.4788707e-01 3.5641396e-01
#  3.5732499e-01 3.6004394e-01 3.6082140e-01 3.6174247e-01 3.6660030e-01
#  3.6758393e-01 3.6818194e-01 3.6867955e-01 3.6868960e-01 3.7079725e-01
#  3.7423500e-01 3.7933883e-01 4.1392773e-01 4.5162693e-01 4.5892659e-01
#  5.5545765e-01 6.1887425e-01 9.2993718e-01 9.8953807e-01 9.9533111e-01
#  9.9580944e-01 9.9583471e-01 9.9686760e-01 9.9691534e-01 9.9712664e-01
#  9.9727589e-01 9.9743396e-01 9.9798977e-01 9.9874532e-01 9.9883646e-01
#  9.9909878e-01 9.9937576e-01 9.9947196e-01 9.9947363e-01 9.9955112e-01
#  9.9973255e-01 9.9980444e-01 9.9981838e-01 9.9982542e-01 9.9982810e-01
# ...

# %%
print(predictions[0].shape)
print(np.unique(predictions[0]))
# Out:
# (569, 1)
# [0 1]
